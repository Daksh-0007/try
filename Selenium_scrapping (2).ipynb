# %%
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
import pandas as pd

# %%
# the website to be scrapped
website="https://www.instahyre.com/search-jobs/"

# get request to the url
opts=Options()
driver=webdriver.Chrome(opts)
driver.get(website)

# creating empty list for the data
data=[]

# %%
# taking total no of pages to be repeated for data collection
pages= 3

# running for loop for different pages upto n pages
for i in range(pages):
    print("Page", i+1)

    # making soup
    html_code=driver.page_source
    soup=BeautifulSoup(html_code,'html.parser')
    
    # all rows in one page
    rows=soup.find_all(class_='row cursor-pointer')
    
    # run loop for each row to get the data by clicking on the view tab
    for row in rows:
        link=row.find('a')['href']

        #printing each link of view tab
        print("directing to link :", link) 
        
        # taking content_driver as a driver for content for each row 
        content_driver = webdriver.Chrome(opts)
        content_driver.get(link)
        
        # making soup for content
        content_html_code = content_driver.page_source
        content_soup = BeautifulSoup(content_html_code, 'html.parser')
        
        # extracting required data from each content page
        
        # link itself contain the job_id https://www.instahyre.com/job-261410-admin-at-indihood-bangalore/
        job_id = int(link.split('-')[1])
        
        # text of tag is itself the job_title
        job_title = content_soup.find("h1").text.strip()
        
        #text of tag is itself the company_name
        company_name = content_soup.find(class_="company-name").text.strip()
        
        #text of tag is itself the experience
        experience = content_soup.find(class_="experience").text.strip()
        
        # text of tag is itself the job location
        job_locations = content_soup.find(class_="job-locations").text.strip().replace(experience, "")
        
        # text of tag is itself the job hr_name
        HR_name = content_soup.find(class_="rec-name").text.strip()
        
        # text of tag in respective attibute
        founded_in = content_soup.find("div", {"ng-if": "employer.company_founded"}).text.strip()
        
        # text of tag in respective attibute
        employees_count = content_soup.find("div", {"ng-if": "employer.employee_count"}).text.strip()
        
        # there are multiple skills in their tag
        skill = content_soup.find(class_="tags job-description-skills")
        
        if skill and skill.children:
            skill=skill.children
        else:
            skill=[skill]
        
        skills_list = []
        
        if skill is not None:
            for j in skill:
                j = j.text.strip()
                if (j and j != "\\n"):
                    skills_list.append(j)
                    
        if skills_list is None:
            skill="N/A"
        else:
            skill= ", ".join(skills_list)
            
        # appending extracted data to data list   
        data.append({"company_name" : company_name, "job_title" : job_title, "job_locations" : job_locations, 
                         "experience" : experience,"hr_name" : HR_name,"founded_in" : founded_in,
                     "employees_count" : employees_count, "skills" : skill, "job_id" : job_id })
        
        # Return to the previous page
        content_driver.back()
        content_driver.quit()
        
    # again clicking the view tab for another row
    next_page = driver.find_element(By.CSS_SELECTOR, '[ng-click="nextPage()"]').click()
    
# printing no of data and data    
print(len(data))
print("data",data)

# converting list into datframe
df = pd.DataFrame(data)
print(df)
# Out:
# Page 1
# directing to link : https://www.instahyre.com/job-261410-admin-at-indihood-bangalore/
# directing to link : https://www.instahyre.com/job-261457-customer-success-analyst-at-insightsoftware-hyderabad/
# directing to link : https://www.instahyre.com/job-257953-business-development-associate-at-makemytrip-bangalore-gurgaon/
# directing to link : https://www.instahyre.com/job-257955-senior-business-development-manager-at-makemytrip-mumbai-ooty-wayanad/
# directing to link : https://www.instahyre.com/job-259461-corporate-sales-manager-at-medibuddy-delhi-gurgaon-noida/
# directing to link : https://www.instahyre.com/job-260537-lead-development-influencer-marketing-at-only-much-louder-bangalore/
# directing to link : https://www.instahyre.com/job-260918-full-stack-engineer-at-quillbot-work-from-home/
# directing to link : https://www.instahyre.com/job-260927-senior-full-stack-engineer-at-quillbot-work-from-home/
# directing to link : https://www.instahyre.com/job-259105-international-voice-process-at-refactor-academy-2-bangalore/
# directing to link : https://www.instahyre.com/job-260553-account-executive-at-wooqer-2-bangalore/
# Page 2
# directing to link : https://www.instahyre.com/job-261410-admin-at-indihood-bangalore/
# directing to link : https://www.instahyre.com/job-261457-customer-success-analyst-at-insightsoftware-hyderabad/
# directing to link : https://www.instahyre.com/job-257953-business-development-associate-at-makemytrip-bangalore-gurgaon/
# directing to link : https://www.instahyre.com/job-257955-senior-business-development-manager-at-makemytrip-mumbai-ooty-wayanad/
# directing to link : https://www.instahyre.com/job-259461-corporate-sales-manager-at-medibuddy-delhi-gurgaon-noida/
# directing to link : https://www.instahyre.com/job-260537-lead-development-influencer-marketing-at-only-much-louder-bangalore/
# directing to link : https://www.instahyre.com/job-260918-full-stack-engineer-at-quillbot-work-from-home/
# directing to link : https://www.instahyre.com/job-260927-senior-full-stack-engineer-at-quillbot-work-from-home/
# directing to link : https://www.instahyre.com/job-259105-international-voice-process-at-refactor-academy-2-bangalore/
# directing to link : https://www.instahyre.com/job-260553-account-executive-at-wooqer-2-bangalore/
# Page 3
# directing to link : https://www.instahyre.com/job-262908-store-manager-at-aza-hyderabad/
# directing to link : https://www.instahyre.com/job-262912-senior-software-engineer-at-coffeebeans-pune/
# directing to link : https://www.instahyre.com/job-262905-principal-engineer-ui-at-fyers-bangalore/
# directing to link : https://www.instahyre.com/job-262920-cpq-developer-at-ltimindtree-2-work-from-home/
# directing to link : https://www.instahyre.com/job-262918-oracle-flexcube-developer-at-ltimindtree-2-work-from-home/
# directing to link : https://www.instahyre.com/job-262923-business-development-manager-at-max-life-insurance-kolkata/
# directing to link : https://www.instahyre.com/job-257381-customer-relations-renewal-agent-at-mybillbook-flobiz-bangalore/
# directing to link : https://www.instahyre.com/job-257375-customer-relations-manager-upsell-agent-at-mybillbook-flobiz-bangalore/
# directing to link : https://www.instahyre.com/job-257080-inside-sales-associate-at-mybillbook-flobiz-greater-noida-noida/
# directing to link : https://www.instahyre.com/job-262922-software-developer-at-supertails-bangalore/
# 30
# data [{'company_name': 'Indihood', 'job_title': 'Admin (Drive)', 'job_locations': 'Bangalore', 'experience': '2-5 Years', 'hr_name': 'Madhavi Vojhala', 'founded_in': 'Founded in 2016', 'employees_count': '10 - 50 employees', 'skills': 'Expense Management, Facility Management, General Management, Office Operations, Operations Management', 'job_id': 261410}, {'company_name': 'insightsoftware', 'job_title': 'Customer Success Analyst (Drive)', 'job_locations': 'Hyderabad', 'experience': '4-8 Years', 'hr_name': 'Keertana Mahamkali', 'founded_in': 'Founded in 2018', 'employees_count': 'More than 1000 employees', 'skills': 'CRM, Customer Interaction, Customer Relationship, Key Account Management', 'job_id': 261457}, {'company_name': 'MakeMyTrip', 'job_title': 'Business Development Associate (Drive)', 'job_locations': 'Bangalore, Gurgaon', 'experience': '0-4 Years', 'hr_name': 'Ankita Singh', 'founded_in': 'Founded in 2000', 'employees_count': 'More than 1000 employees', 'skills': 'Business Development, Revenue Management, Sales', 'job_id': 257953}, {'company_name': 'MakeMyTrip', 'job_title': 'Senior Business Development Manager (Drive)', 'job_locations': 'Mumbai, Ooty, Wayanad', 'experience': '2-5 Years', 'hr_name': 'Ankita Singh', 'founded_in': 'Founded in 2000', 'employees_count': 'More than 1000 employees', 'skills': 'Business Development, Corporate Sales, Key Account Management, Microsoft Excel, Microsoft PowerPoint, Sales', 'job_id': 257955}, {'company_name': 'MediBuddy', 'job_title': 'Corporate Sales Manager (Drive)', 'job_locations': 'Delhi, Gurgaon, Noida', 'experience': '6-10 Years', 'hr_name': 'Gayathri NB HR  Talent Acquisition', 'founded_in': 'Founded in 2013', 'employees_count': 'More than 1000 employees', 'skills': 'Business Development, Field Work, Lead Generation, Sales', 'job_id': 259461}, {'company_name': 'Only Much Louder', 'job_title': 'Lead Development (Influencer Marketing) (Drive)', 'job_locations': 'Bangalore', 'experience': '2-6 Years', 'hr_name': 'Tuzar Baria', 'founded_in': 'Founded in 2001', 'employees_count': '50 - 200 employees', 'skills': 'Business Development, CRM, Lead Generation, Marketing', 'job_id': 260537}, {'company_name': 'QuillBot', 'job_title': 'Full Stack Engineer (Drive)', 'job_locations': 'Work From Home', 'experience': '3-5 Years', 'hr_name': 'Somiya Garg', 'founded_in': 'Founded in 2017', 'employees_count': '50 - 200 employees', 'skills': 'Agile, Git, JavaScript, Jest, Mocha, MongoDB, MySQL, Node.js, React.js, RxJS', 'job_id': 260918}, {'company_name': 'QuillBot', 'job_title': 'Senior Full Stack Engineer (Drive)', 'job_locations': 'Work From Home', 'experience': '5-8 Years', 'hr_name': 'Somiya Garg', 'founded_in': 'Founded in 2017', 'employees_count': '50 - 200 employees', 'skills': 'Agile, Git, JavaScript, Jest, Mocha, MongoDB, MySQL, Node.js, React.js, RxJS', 'job_id': 260927}, {'company_name': 'Refactor Academy', 'job_title': 'International Voice Process (Drive)', 'job_locations': 'Bangalore', 'experience': '0-4 Years', 'hr_name': 'Alisha', 'founded_in': 'Founded in 2022', 'employees_count': '10 - 50 employees', 'skills': 'Customer Service, International BPO', 'job_id': 259105}, {'company_name': 'Wooqer', 'job_title': 'Account Executive (Drive)', 'job_locations': 'Bangalore', 'experience': '3-5 Years', 'hr_name': 'Nakita Fernandes', 'founded_in': 'Founded in 2014', 'employees_count': '50 - 200 employees', 'skills': 'Business Development, CRM, Corporate Sales, Google Workspace, Microsoft Office, Sales', 'job_id': 260553}, {'company_name': 'Indihood', 'job_title': 'Admin (Drive)', 'job_locations': 'Bangalore', 'experience': '2-5 Years', 'hr_name': 'Madhavi Vojhala', 'founded_in': 'Founded in 2016', 'employees_count': '10 - 50 employees', 'skills': 'Expense Management, Facility Management, General Management, Office Operations, Operations Management', 'job_id': 261410}, {'company_name': 'insightsoftware', 'job_title': 'Customer Success Analyst (Drive)', 'job_locations': 'Hyderabad', 'expe ...
#            company_name                                          job_title
# 0              Indihood                                      Admin (Drive)  \
# 1       insightsoftware                   Customer Success Analyst (Drive)
# 2            MakeMyTrip             Business Development Associate (Drive)
# 3            MakeMyTrip        Senior Business Development Manager (Drive)
# 4             MediBuddy                    Corporate Sales Manager (Drive)
# 5      Only Much Louder    Lead Development (Influencer Marketing) (Drive)
# 6              QuillBot                        Full Stack Engineer (Drive)
# 7              QuillBot                 Senior Full Stack Engineer (Drive)
# 8      Refactor Academy                International Voice Process (Drive)
# 9                Wooqer                          Account Executive (Drive)
# 10             Indihood                                      Admin (Drive)
# 11      insightsoftware                   Customer Success Analyst (Drive)
# 12           MakeMyTrip             Business Development Associate (Drive)
# 13           MakeMyTrip        Senior Business Development Manager (Drive)
# 14            MediBuddy                    Corporate Sales Manager (Drive)
# 15     Only Much Louder    Lead Development (Influencer Marketing) (Drive)
# 16             QuillBot                        Full Stack Engineer (Drive)
# 17             QuillBot                 Senior Full Stack Engineer (Drive)
# 18     Refactor Academy                International Voice Process (Drive)
# 19               Wooqer                          Account Executive (Drive)
# 20                  Aza                                      Store Manager
# 21          CoffeeBeans                           Senior Software Engineer
# 22                Fyers                            Principal Engineer - UI
# 23          LTIMindtree                                      CPQ Developer
# 24          LTIMindtree                          Oracle Flexcube Developer
# 25   Max Life Insurance                       Business Development Manager
# 26  MyBillBook (FloBiz)         Customer Relations - Renewal Agent (Drive)
# 27  MyBillBook (FloBiz)  Customer Relations Manager - Upsell Agent (Drive)
# 28  MyBillBook (FloBiz)                     Inside Sales Associate (Drive)
# 29           Supertails                                 Software Developer
#
#             job_locations   experience                             hr_name
# 0               Bangalore    2-5 Years                     Madhavi Vojhala  \
# 1               Hyderabad    4-8 Years                  Keertana Mahamkali
# 2      Bangalore, Gurgaon    0-4 Years                        Ankita Singh
# 3   Mumbai, Ooty, Wayanad    2-5 Years                        Ankita Singh
# 4   Delhi, Gurgaon, Noida   6-10 Years  Gayathri NB HR  Talent Acquisition
# 5               Bangalore    2-6 Years                         Tuzar Baria
# 6          Work From Home    3-5 Years                         Somiya Garg
# 7          Work From Home    5-8 Years                         Somiya Garg
# 8               Bangalore    0-4 Years                              Alisha
# 9               Bangalore    3-5 Years                    Nakita Fernandes
# 10              Bangalore    2-5 Years                     Madhavi Vojhala
# 11              Hyderabad    4-8 Years                  Keertana Mahamkali
# 12     Bangalore, Gurgaon    0-4 Years                        Ankita Singh
# 13  Mumbai, Ooty, Wayanad    2-5 Years                        Ankita Singh
# 14  Delhi, Gurgaon, Noida   6-10 Years  Gayathri NB HR  Talent Acquisition
# 15              Bangalore    2-6 Years                         Tuzar Baria
# 16         Work From Home    3-5 Years                         Somiya Garg
# 17         Work From Home    5-8 Years                         Somiya Garg
# 18              Bangalore    0-4 Years                              Alisha
# 19              Bangalore    3-5 Years                    Nakita Fernandes
# 20              Hyderabad  10-15 Years                    Aashi Srivastava
# 21                   Pune    5-7 Years                    Gokul Vellingiri
# 22              Bangalore   9-14 Years                         Monu Sharma
# 23         Work From Home   5-10 Years                       Bhaskar Anand
# 24         Work From Home   5-10 Years                       Bhaskar Anand
# 25                Kolkata    2-6 Years                       Piyush Mishra
# 26              Bangalore    2-3 Years                        Rabi Agrawal
# 27              Bangalore    2-3 Years                        Rabi Agrawal
# 28   Greater Noida, Noida    1-3 Years                        Rabi Agrawal
# 29              Bangalore    2-5 Years                          Sharmila M
#
#          founded_in           employees_count
# 0   Founded in 2016         10 - 50 employees  \
# 1   Founded in 2018  More than 1000 employees
# 2   Founded in 2000  More than 1000 employees
# 3   Founded in 2000  More than 1000 employees
# 4   Founded in 2013  More than 1000 employees
# 5   Founded in 2001        50 - 200 employees
# 6   Founded in 2017        50 - 200 employees
# 7   Founded in 2017        50 - 200 employees
# 8   Founded in 2022         10 - 50 employees
# 9   Founded in 2014        50 - 200 employees
# 10  Founded in 2016         10 - 50 employees
# 11  Founded in 2018  More than 1000 employees
# 12  Founded in 2000  More than 1000 employees
# 13  Founded in 2000  More than 1000 employees
# 14  Founded in 2013  More than 1000 employees
# 15  Founded in 2001        50 - 200 employees
# 16  Founded in 2017        50 - 200 employees
# 17  Founded in 2017        50 - 200 employees
# 18  Founded in 2022         10 - 50 employees
# 19  Founded in 2014        50 - 200 employees
# 20  Founded in 2004       200 - 500 employees
# 21  Founded in 2017        50 - 200 employees
# 22  Founded in 2015        50 - 200 employees
# 23  Founded in 1996  More than 1000 employees
# 24  Founded in 1996  More than 1000 employees
# 25  Founded in 2000  More than 1000 employees
# 26  Founded in 2019       200 - 500 employees
# 27  Founded in 2019       200 - 500 employees
# 28  Founded in 2019       200 - 500 employees
# 29  Founded in 2021        50 - 200 employees
#
#                                                skills  job_id
# 0   Expense Management, Facility Management, Gener...  261410
# 1   CRM, Customer Interaction, Customer Relationsh...  261457
# 2     Business Development, Revenue Management, Sales  257953
# 3   Business Development, Corporate Sales, Key Acc...  257955
# 4   Business Development, Field Work, Lead Generat...  259461
# 5   Business Development, CRM, Lead Generation, Ma...  260537
# 6   Agile, Git, JavaScript, Jest, Mocha, MongoDB, ...  260918
# 7   Agile, Git, JavaScript, Jest, Mocha, MongoDB, ...  260927
# 8                 Customer Service, International BPO  259105
# 9   Business Development, CRM, Corporate Sales, Go...  260553
# 10  Expense Management, Facility Management, Gener...  261410
# 11  CRM, Customer Interaction, Customer Relationsh...  261457
# 12    Business Development, Revenue Management, Sales  257953
# 13  Business Development, Corporate Sales, Key Acc...  257955
# 14  Business Development, Field Work, Lead Generat...  259461
# 15  Business Development, CRM, Lead Generation, Ma...  260537
# 16  Agile, Git, JavaScript, Jest, Mocha, MongoDB, ...  260918
# 17  Agile, Git, JavaScript, Jest, Mocha, MongoDB, ...  260927
# 18                Customer Service, International BPO  259105
# 19  Business Development, CRM, Corporate Sales, Go...  260553
# 20  Sales, Store Operations, MIS, Customer Relatio...  262908
# 21        Gradle, JUnit, Java, Microservices, MongoDB  262912
# 22       Angular, React.js, JavaScript, Jest, Cypress  262905
# 23                                         Oracle CPQ  262920
# 24           Flexcube, SQL, PL-SQL, JavaScript, MySQL  262918
# 25          Sales, Business Development, Direct Sales  262923
# 26             Customer Interaction, Customer Service  257381
# 27             Customer Interaction, Customer Service  257375
# 28  Business Development, Direct Sales, Sales, Tel...  257080
# 29                         Node.js, React Native, SQL  262922

# %%
df.to_excel('F://scrap_data//data_5.xlsx', columns=['company_name', 'job_title', 'job_locations', 'experience', 'hr_name', 
                                                    'founded_in', 'employees_count', 'skills','job_id'], index=False)
